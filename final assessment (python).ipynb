# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#       _type    _id     _score  \
# 0    movies     97  20.848059
# 1    movies    507  10.478757
# 2    movies    811   9.831051
# 3   tvshows  25222   9.288745
# 4    movies    757   9.140831
# 5    movies    588   9.029721
# 6    movies    809   8.968119
# 7   tvshows    106   8.586343
# 8    movies    759   8.351236
# 9    movies    810   8.224913
# 10   movies    392   8.171915
# 11   movies    629   8.070547
# 12   movies    744   7.992266
# 13   movies    838   7.869948
# 14   movies    847   7.856983
# 15   movies     33   7.301026
# 16   movies    535   7.185848
# 17   movies    819   7.033730
# 18   movies    401   6.981756
# 19   movies    787   6.981756
# 20   movies    663   6.489738
# 21   movies    577   6.466314
# 22   movies    707   6.466314
# 23   movies    820   6.368584
# 24   movies    280   6.200307
# 25  tvshows    341   6.020742
# 26   movies    766   5.990043
# 27   movies    402   5.848304
# 28   movies    482   5.848304
# 29   movies    462   5.628126
# ...

# %%
df['_source']
# Out:
# 0     {'cast': ['Jeff Bridges', 'Bruce Boxleitner', ...
# 1     {'cast': ['Eric Stoltz', 'Julie Delpy', 'Jean-...
# 2     {'cast': ['Bruce Dern', 'Cliff Potts', 'Ron Ri...
# 3     {'cast': ['Ron Rifkin', 'Eddie Barth', 'Charle...
# 4     {'cast': ['Margaret Rutherford', 'Ron Moody', ...
# 5     {'cast': ['Radha Mitchell', 'Sean Bean', 'Jode...
# 6     {'cast': ['Mike Myers', 'Eddie Murphy', 'Camer...
# 7     {'cast': ['Andy Griffith', 'Ron Howard', 'Fran...
# 8     {'cast': ['Jane Russell', 'Marilyn Monroe', 'C...
# 9     {'cast': ['Mike Myers', 'Eddie Murphy', 'Camer...
# 10    {'cast': ['Juliette Binoche', 'Alfred Molina',...
# 11    {'cast': ['Stephen Baldwin', 'Kevin Spacey', '...
# 12    {'cast': ['Tom Cruise', 'Kelly McGillis', 'Val...
# 13    {'cast': ['Richard Dreyfuss', 'Ron Howard', 'P...
# 14    {'cast': ['Warwick Davis', 'Val Kilmer', 'Joan...
# 15    {'cast': ['Clint Eastwood', 'Gene Hackman', 'M...
# 16    {'cast': ['Jennifer Beals', 'Michael Nouri', '...
# ...
